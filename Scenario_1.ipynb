# %% [markdown]
# ### Scenario 1 : Incoming Freshman asking for guidance on what kinds of classes to take in their first semester
#
# **Chat GPT Said**
#
# Of course! I’m here to support you in a way that feels clear, kind, and helpful—especially if you’re figuring a lot of this out on your own. 😊 Whether you're trying to choose a major, feeling unsure about something in class, or thinking about your future plans, I’ll walk with you through it. You don’t have to have it all figured out right now. So, what’s on your mind?
#
# To start, can I ask what year you’re in and what kinds of things you’re interested in—either in school or beyond? That’ll help me get a better sense of how to support you.
#
# **You Said**
#
# Hi I am an incoming freshman at UPenn, and I'm considering becoming a lawyer for after undergrad. I need guidance for what classes I should take this semester
#
# **Chat GPT Said**
#
# That’s awesome, and congratulations on starting your journey at UPenn! Since you’re considering law school after undergrad, there are a few classes that could be helpful to start exploring now. At this stage, it’s good to focus on building a strong foundation in skills like critical thinking, writing, and analyzing complex texts—these are all key for law school.
#
# Here’s a mix of classes that might align well with your interests:
#
# 1. **Introduction to Political Science or American Government:** Understanding how laws are created and the political system can be really beneficial for a future lawyer.
#
# 2. **Writing and Composition:** Law school requires strong writing skills, so starting with writing-focused classes will help you develop the clarity and structure needed for legal writing.
#
# 3. **Philosophy (Logic or Ethics):** Philosophy classes, especially in logic, can help you with critical reasoning, and ethics will give you a good foundation in moral questions, which is important for law.
#
# 4. **Sociology or History:** These subjects help you understand society, its institutions, and how they interact with the law, which is critical for a well-rounded perspective.
#
# 5. **Public Speaking:** Communication is key for lawyers, so any opportunities to practice speaking and presenting will give you an edge.
#
# I would also suggest you check out any pre-law advising or student groups at UPenn—these could help you connect with others interested in law and get advice specific to your goals.
#
# How are you feeling about the idea of starting classes this semester? Is there any subject area that stands out to you the most or feels like it might be challenging?
#
# **You Said**
#
# I do have an interest in Sociology and am considering majoring in it but am not completely married to the idea. I'm excited to challenge myself in classes this semester, but need to figure out my schedule
#
# **Chat GPT Said**
#
# It’s great that you’re open to challenging yourself this semester! Sociology is a fantastic major if you’re interested in understanding society, human behavior, and how laws interact with these broader systems, so it could tie in well with your future law aspirations. But it’s perfectly okay if you’re not completely sure yet—that’s the beauty of being in college; you can explore your interests and refine your path along the way.
#
# To help figure out your schedule, let’s think about a balance. Here’s a possible structure:
#
# 1. **Introductory Sociology Class:** This would give you a taste of the major and see if it feels like a good fit. You could also take a course like Social Problems or Introduction to Social Theory to get a broad sense of the field.
# 2.  **Foundational Writing Class:** A writing class focused on analytical essays or critical thinking will serve you well, especially if you want to hone your argumentation and writing style for future law courses.
# 3.  **A Government or Political Science Course:** A class that introduces you to political systems could give you a helpful context for law and policy.
# 4.  **Elective/General Ed Course:** This could be something completely different you’re curious about—maybe philosophy, economics, or even something creative like art history. Keeping your schedule diverse will keep things exciting.
# 5.  **A Skill-Building Class:** Consider something that will help you with public speaking or debating (like a communication class or a rhetoric course). Law school requires a lot of oral advocacy, so any chance to practice presenting ideas will be valuable.
#
# If you're unsure about Sociology, it might be helpful to try a few Sociology-related courses and see how they feel. Maybe even chat with a Sociology advisor or some professors to see if their courses spark something for you.
#
# What classes are you looking at so far, and do any of these suggestions sound like something you’d want to try this semester?
#
# **You Said**
#
# What gen ed am i supposed to be taking now?
#
# **Chat GPT Said**
#
# Great question! At UPenn, as an incoming freshman, you’ll typically be starting with a few general education (gen ed) requirements to ensure you get a well-rounded education. These are designed to expose you to different areas of knowledge, and they can be a mix of subjects that help develop key skills for any field, including law.
#
# Here’s a basic breakdown of what you might be looking at for gen eds, but I would definitely suggest double-checking with your academic advisor to make sure you’re on track for your specific school within UPenn (like the College of Arts and Sciences or another division).
#
# ### Common Gen Ed Categories at UPenn:
#
# 1. **Humanities & Social Sciences:** This could be a Sociology or Philosophy course, which fits well with your interest in law. Other options might include history, anthropology, or political science.
#
# 2. **Natural Sciences:** A science course (either with or without a lab). This could be something basic like biology or chemistry, or even a course that integrates science with society (for example, environmental science).
#
# 3. **Quantitative Reasoning:** If you haven’t yet, you may need a math course that helps develop analytical thinking. Since you're exploring different fields, you could take a statistics or basic math course to fulfill this requirement, which also comes in handy for analyzing data, a useful skill in many areas, including law.
#
# 4. **Cross-Cultural Analysis or Global Perspectives:** This could be an elective focusing on global issues, cultures, or history outside of the U.S. It’s a great opportunity to understand how laws work in different countries, which can be helpful when thinking about international law.
#
# 5. **Writing:** You’ll likely need to fulfill a writing requirement early on, which is something you could fulfill with a Writing Seminar or similar course designed to help develop critical writing and thinking skills.
#
# It’s important to look at how these classes fit into your broader plan and make sure they align with your interests. Some of the classes might even overlap with your intended career in law or your major in Sociology.
#
# Do any of these categories sound like they might be a good fit for you this semester? Or are there any specific classes you’ve been looking into already?
#
# **You Said:**
#
# What balance gen ed and my exploratory classes should i take this semester?
#
# **Chat GPT Said:**
#
# Creating a balanced schedule that includes both general education (gen ed) courses and exploratory classes is a great way to start your college journey, especially as you navigate different interests and build a strong foundation for future law school. Here’s how you can think about balancing both:
#
# ### 1. Start with Core Gen Ed Requirements
#
# You’ll likely want to tackle some of your gen ed requirements early on to ensure you’re covering all the necessary areas over time. Since you’re interested in Sociology and possibly law, you can try to pick gen eds that align with those interests while fulfilling broader requirements.
#
# * **Writing:** If you haven’t already, start with a writing class. Writing and argumentation are central to law, so starting early with writing-focused courses will help you in the long run.
#
# * **Quantitative Reasoning:** If you need a math or statistics class, this is a good time to knock it out. It’s also useful for analyzing data, which is a skill in law, especially if you’re dealing with cases or legislation that involve data interpretation.
#
# ### 2. Exploratory Classes (that could inform your future plans)
#
# Since you’re still figuring out whether you want to major in Sociology, I suggest exploring that interest this semester with a class or two. Choose courses that provide an introduction to Sociology and its key concepts, but also look for classes that align with law or your other interests.
#
# * **Sociology Intro Course:** Consider a course like Introduction to Sociology or Social Problems to get a broad sense of the field.
#
# * **Political Science or Government:** A class on American government or political systems could help lay the groundwork for a future in law.
#
# * **Philosophy:** A class in logic or ethics would be great if you want to develop your critical thinking and reasoning skills.
#
# These exploratory courses will give you a taste of what these areas are like and help you decide if you want to continue in them.
#
# ### 3. Balance Your Schedule
#
# Aim for a mix of courses that challenge you in different ways—both intellectually and time-wise. Here’s a potential balance:
#
# * **1 Gen Ed (Writing or Quantitative Reasoning):** These are foundational, and it’s good to get them out of the way early.
#
# * **1-2 Exploratory Courses (Sociology, Philosophy, Political Science):** Pick subjects you’re curious about but not too heavy. You don’t want to overload yourself with difficult courses if it’s your first semester.
#
# * **1 Course of Interest (Public Speaking, Debate, or a Course Outside Your Major):** A skill-building class that’s not directly related to your major, but still something valuable for your career goals, like a public speaking or communication class.
#
# ### 4. Make Sure You Leave Room for Self-Care and Extracurriculars
#
# College life can be demanding, especially when balancing a full course load, so it’s important to leave time for self-care, activities, or student groups that interest you. Getting involved in clubs like the pre-law society, or even something like student government, could give you a feel for the world of law while also making friends and networking.
#
# **Sample First Semester Schedule:**
#
# * **Intro to Sociology** (Exploratory)
#
# * **Writing 101** (Gen Ed)
#
# * **Intro to Political Science** (Exploratory)
#
# * **Statistics or Math for Social Sciences** (Gen Ed)
#
# * **Public Speaking or Communication** (Skill Building)
#
# How does this balance sound to you? Do any of these types of classes jump out at you, or are there other areas you’d like to explore?
#
# **You Said**:
#
# I thought I was only allowed to take 4 classes for my first semester?
#
# **Chat GPT Said:**
#
# You’re right! Many universities, including UPenn, typically recommend that first-year students take 4 courses during their first semester. It’s a manageable load as you adjust to the demands of college and get comfortable with the academic environment.
#
# Given that, you’ll want to choose your 4 courses thoughtfully so you have a balance of challenging but doable classes. Here’s how you can think about structuring your semester with just 4 classes:
#
# ### 1. One Gen Ed Course (Writing or Quantitative Reasoning)
#
# Pick a gen ed course that will lay the foundation for your future academic work and legal career.
#
# * **Writing 101:** A strong writing course is essential for developing the skills you'll need in law school.
#
# * **Math or Statistics:** If you need to fulfill your quantitative reasoning requirement, this is a good time to start. It’s important but manageable if you choose a course designed for social science majors.
#
# ### 2. One Introductory Sociology Course (Exploratory)
#
# Since you’re considering Sociology, it makes sense to try an introductory class that will give you a broad view of the field.
#
# * *Introduction to Sociology* or *Social Problems* are good starting points.
#
# ### 3. One Political Science or Government Course (Exploratory)
#
# A course in government or political science will help you build an understanding of how laws are created and how political systems work. This is especially helpful if you're considering law school.
#
# *Introduction to Political Science* or *American Government* could be great options.
#
# ### 4. One Skills-Based Class (Public Speaking or Communication)
#
# A public speaking or communication class will help you develop skills you'll need as a future lawyer, like presenting arguments and communicating clearly.
#
# * *Public Speaking* or *Argumentation and Debate* would both be good options.
#
# **Sample First Semester Schedule (4 Courses):**
#
# * **Writing 101** (Gen Ed)
#
# * **Intro to Sociology** (Exploratory)
#
# * **Introduction to Political Science** (Exploratory)
#
# * **Public Speaking** (Skills-Based)
#
# This schedule gives you a nice balance of academic requirements and exploration without overwhelming you.
#
# What do you think of this plan? Does it sound like a good starting point for your first semester?
