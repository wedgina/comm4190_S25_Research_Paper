# %% [markdown]
# ### Scenario 4 : Upcoming college graduate checking in with advisor to determine if they are truly on track to graduate
#
# Absolutely — I'm here for you. Whether you're trying to figure out your major, feeling unsure about a class, juggling family responsibilities, or just need to talk through something, I’ve got you. College can be confusing and overwhelming sometimes, especially if you're doing it without a lot of outside guidance — but you don't have to figure it all out alone.
#
# To start, would you mind sharing a bit about where you are in your college journey? For example, are you just starting out, or have you been here for a little while? And is there anything specific on your mind right now that you’d like to talk through — academics, career stuff, personal life, anything?
#
# I'm here to listen and help however I can.
#
# **You Said:**
# Wedgina_Norelus_UT_2025-04-18T20_49_05.pdf
# PDF
# I'm an uprising senior at UPenn, and want to check in on whether I am on track to graduate a the end of they year. I'm majoring in cognitive science (concentration in cognition and computation) and minoring in data science and analytics. I've shared my transcript which shows which classes I have taken
#
# **ChatGPT said:**
# Thank you for sharing your transcript — and congratulations on making it to senior year! That’s a big deal, especially navigating everything as a first-gen student. I can already see how much work and dedication you’ve put in across a wide range of courses.
#
# To make sure you’re on track to graduate, we’ll need to check a few things together:
#
# ### 🧠 Major in Cognitive Science (Cognition & Computation concentration)
#
# Penn’s **Cognitive Science major with a Cognition & Computation concentration** usually includes:
#
# 1. **Intro to CogSci (COGS 1001)** – ✅ Taken Fall 2023
# 2. **Introductory courses from core areas:**
#      - **Computer Science (e.g., CIS 1100, 1200)** – ✅ Taken
#      - **Linguistics (LING 0001)** – ✅ Taken
#      - **Philosophy (PHIL 1170, PHIL 2680)** – ✅ Taken
#      - **Neuroscience (NRSC 2249)** – ✅ Taken
#      - **Psychology (PSYC 0001)** – ✅ Taken
# 3. **Computational Methods** – Looks like:
#     * CIS 1100, CIS 1200 ✅
#     * NRSC 3334 (Computational Neuroscience Lab) ✅
#     * OIDD 2900 (Decision Processes) ✅
#     * PSCI 1800 (Intro Data Sci) ✅
# 4. **Capstone or advanced seminar?** — I didn’t see a CogSci senior seminar/capstone, so that might be one thing to double-check with your advisor or major department. Some concentrations require it.
#
# ### 📊 Minor in Data Science & Analytics
#
# This minor usually includes:
#
# 1. **Intro Stats (STAT 1110)** – ✅ Taken
# 2. **Intro to Data Science (PSCI 1800)** – ✅ Taken
# 3. **Applied/advanced course (PSCI 3800)** – ✅ Taken
# 4. Plus electives – OIDD 2900, NRSC 3334, and CIS 1200 might count depending on the department’s list.
#
# I'd recommend confirming with your minor advisor whether all your electives were accepted for the minor—usually there's a form submitted declaring which classes you’re counting.
#
# ### 📚 General Requirements for College of Arts & Sciences
#
# * **Total CUs needed to graduate:** Typically **32–36 CUs**
#   - Your transcript shows you’ve completed about **31 CUs** so far (some courses were 2 CU like SPAN 0340), so if you take a full course load in Fall 2025 (like 4–5 CU), you'll likely be in the clear.
# * **Sector Requirements (like humanities, society, natural science, etc.)** – Based on your wide variety of classes, you’ve probably completed most, but I’d want to double-check this with you. You may be able to see them listed on **Path@Penn's Degree Audit** or we can go through them together if you’re not sure.
#
# Would you like to walk through your **college-wide sector requirements** next to make sure you’re covered there? Or is there a class you’re worried about not counting toward your major/minor?
#
# And just to double-check, are you planning to take classes this upcoming **Fall 2025** semester only, or are you hoping to be done by the **end of summer**?
#
# You’re so close — let’s make sure everything’s locked in.
#
#
# **You Said:**
# https://web.sas.upenn.edu/cogsci/major/, am i on track to graduate
#
#
# **ChatGPT said:**
# Thank you for sharing your transcript and the link to the Cognitive Science major requirements. Based on the information provided, let's assess your progress toward graduation.
#
# ### 🧠 Cognitive Science Major (Computation & Cognition Concentration)
#
# The major requires **16 unique course units (CUs)**, comprising:
#
# 1. **Core Course (1 CU):**
#
# * **COGS 1001 – Introduction to Cognitive Science:** ✔️ Completed in Fall 2023.
#
# 2. **Breadth Requirement (6 CUs):**
#
# * Psychology: ✔️ PSYC 0001 – Introduction to Experimental Psychology.
# * Computation: ✔️ CIS 1100 – Introduction to Computer Programming.
# * Linguistics: ✔️ LING 0001 – Introduction to Linguistics.
# * Philosophy: ✔️ PHIL 1170 – History of Modern Philosophy.
# * Neuroscience: ✔️ NRSC 2249 – Cognitive Neuroscience.
# * Additional Breadth Course: ✔️ PHIL 2680 – Introduction to Metaphysics.
#
# 3. **Concentration in Computation & Cognition (9 CUs):**
#
# * CIS 1200 – Programming Languages and Techniques I: ✔️
# * NRSC 3334 – Computational Neuroscience Lab: ✔️
# * OIDD 2900 – Decision Processes: ✔️
# * PSCI 1800 – Introduction to Data Science: ✔️
# * PSCI 3800 – Applied Data Science: ✔️
# * MATH 170 – Ideas in Mathematics: ✔️
# * STAT 1110 – Introductory Statistics: ✔️
# * LING 0750 – Language and Thought: ✔️
# * COGS 1001 – Introduction to Cognitive Science: ✔️ (Note: Already counted as core course.)
#
# *Note: Some courses may fulfill both breadth and concentration requirements, but each course can only count toward one requirement.*
#
# ### 📊 Data Science and Analytics Minor
#
# The minor typically requires:
#
# 1. STAT 1110 – Introductory Statistics: ✔️
# 2. PSCI 1800 – Introduction to Data Science: ✔️
# 3. PSCI 3800 – Applied Data Science: ✔️
# 4. OIDD 2900 – Decision Processes: ✔️
#
# *Note: It's important to confirm with your minor advisor whether these courses fulfill the minor requirements, as some courses may overlap with your major.*
#
# #### 📚 General Education and Total Credit Requirements
#
# * **Total CUs Completed:** Approximately 31 CUs.
# * **Minimum CUs Required for Graduation:** 36 CUs.
# * **Remaining CUs Needed:** Approximately 5 CUs.
#
# *Note: The exact number may vary based on specific program requirements and any additional credits earned.*
#
# ### ✅ Next Steps
#
# To ensure you're on track to graduate:
#
# 1. **Review Your Degree Audit:** Check your degree audit on Path@Penn to confirm the courses counted toward each requirement.
# 2. **Consult with Your Academic Advisor:** Discuss your progress and confirm that all requirements are being met.
# 3. **Plan Remaining Courses:** Ensure that your remaining courses fulfill any outstanding requirements.
#
# If you have any specific concerns or questions about your course selections or requirements, feel free to share them, and I can provide more detailed guidance.
#
#
# Sources
# **You Said:**
# https://catalog.upenn.edu/undergraduate/programs/data-science-analytics-minor/ Am i on track to fulfill the minor
#
# **ChatGPT said:**
# Thank you for sharing your transcript and the link to the Data Science and Analytics minor requirements. Based on the information provided, let's assess your progress toward completing the minor.
#
# ### 📊 Data Science and Analytics Minor Requirements
# The minor consists of six courses, divided as follows:
#
# 1. **Foundational Courses (3 courses):**
#
# * **Introductory Data Science and Programming (1 course):**
#   - Acceptable courses include:
#     - PSCI 1800 – Introduction to Data Science
#     - CIS 1050 – Computational Data Exploration
#     - COMM 2550 – Foundations in Data Science for Communication
#     - LING 0700 – Data Science for Studying Language and the Mind
#     - PHYS 1100 – Foundations of Data Science
#     - PHYS 2260 – Introduction to Computational Physics
#     - COMM 3180 – Stories From Data: Introduction to Programming for Data Journalism
#   - **Your coursework:** ✔️ PSCI 1800 – Introduction to Data Science
#  - **Statistics (1 course):**
#    - Acceptable courses include:
#      - STAT 1120 – Introductory Statistics
#      - STAT 1020 – Introductory Business Statistics
#      - SOCI 2010 – Social Statistics
#      - ECON 2300 – Statistics for Economists
#      - ESE 3010 – Engineering Probability
#      - PHYS 3358 – Data Analysis for the Natural Sciences I: Fundamentals
#      - PSCI 1801 – Statistical Methods PSCI
#      - BIOL 2510 – Statistics for Biologists
#      - CRIM 1200 – Statistics for the Social Sciences I
#     - **Your coursework:** ✔️ STAT 1110 – Introductory Statistics
#   - **Applied Data Science (1 course):**
#     - Acceptable courses include:
#       - PSCI 3800 – Applied Data Science
#       - STAT 4420 – Introduction to Bayesian Data Analysis
#       - STAT 4710 – Modern Data Mining
#       - ECON 4330 – Econometric Machine Learning Methods and Models
#       - BIOL 4511 – Biological Data Analysis
#     - **Your coursework:** ✔️ PSCI 3800 – Applied Data Science
# 2. **Elective Courses (3 courses):**
#
# * These should have a strong link to data science. Acceptable electives include:
#   - OIDD 2900 – Decision Processes
#   - NRSC 3334 – Computational Neuroscience Lab
#   - CIS 1200 – Programming Languages and Techniques I
# * **Your coursework:**
#   - ✔️ OIDD 2900 – Decision Processes
#   - ✔️ NRSC 3334 – Computational Neuroscience Lab
#   - ✔️ CIS 1200 – Programming Languages and Techniques I
#
# ### ✅ Summary
#
# Based on your transcript:
#
# * **Foundational Courses:** All three required courses have been completed.
# * **Elective Courses:** Three relevant electives have been completed.
#
# Therefore, you appear to be on track to fulfill the requirements for the Data Science and Analytics minor.
#
# ### 📌 Next Steps
#
# To ensure everything is in order:
#
# **1. Consult with Your Minor Advisor:**
# * Confirm that all courses are accepted toward the minor.
# * Discuss any additional requirements or paperwork needed.
#
# **2. Review Your Degree Audit:**
# * Check your degree audit on Path@Penn to verify that all courses are correctly applied to the minor.
#
# **3. Plan for Remaining Requirements:**
# * Ensure that any remaining courses or credits needed for graduation are scheduled.
#
# If you have any further questions or need assistance with planning your remaining coursework, feel free to ask.
